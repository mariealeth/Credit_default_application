# %%
import pandas as pd
from sklearn import datasets
from evidently.dashboard import Dashboard  
from evidently.report import Report
from evidently.dashboard.tabs import DataDriftTab
from evidently.metric_preset import DataDriftPreset, TargetDriftPreset, DataQualityPreset
# Out:
# /opt/anaconda3/envs/openclassrooms/lib/python3.9/site-packages/evidently/analyzers/__init__.py:3: UserWarning: analyzers are deprecated, use metrics instead
#   warnings.warn("analyzers are deprecated, use metrics instead")
# /opt/anaconda3/envs/openclassrooms/lib/python3.9/site-packages/evidently/dashboard/__init__.py:8: UserWarning: dashboards are deprecated, use metrics instead
#   warnings.warn("dashboards are deprecated, use metrics instead")

# %%
#%cd /Users/aleth/Documents/Python/0penclassroom/P7/P7_docker_compose_copy/streamlit-frontend/
# Out:
# /Users/aleth/Documents/Python/0penclassroom/P7/P7_docker_compose_copy/streamlit-frontend

# %% [markdown]
# # Données

# %%
data_full = pd.read_csv('data_transformed_full.csv')
data_full
# Out:
#         Unnamed: 0  index  SK_ID_CURR  TARGET  NAME_CONTRACT_TYPE  \
# 0                0      0      100002     1.0                   0
# 1                1      1      100003     0.0                   0
# 2                2      2      100004     0.0                   1
# 3                3      3      100006     0.0                   0
# 4                4      4      100007     0.0                   0
# ...            ...    ...         ...     ...                 ...
# 356246      356250  48739      456221     NaN                   0
# 356247      356251  48740      456222     NaN                   0
# 356248      356252  48741      456223     NaN                   0
# 356249      356253  48742      456224     NaN                   0
# 356250      356254  48743      456250     NaN                   0
#
#         CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0                 0             0                0             0
# ...

# %%
features_20 = pd.read_csv('features_20.csv')

# %%
features_20 = list(features_20['feature'])

# %%
train_20 = data_full[data_full['TARGET'].notna()].loc[:, features_20]
train_20.shape
# Out:
# (307507, 20)

# %%
test_20 = data_full[data_full['TARGET'].isna()].loc[:, features_20]
test_20.shape
# Out:
# (48744, 20)

# %% [markdown]
# # Data drift dashboard

# %%
import pandas as pd
from sklearn import datasets
from evidently.report import Report
from evidently.metric_preset import DataDriftPreset

# %% [markdown]
# ## Avec 100 nouvelles valeurs

# %%
data_drift_report_100 = Report(metrics=[DataDriftPreset(),])
data_drift_report_100.run(current_data=test_20.iloc[:100], reference_data=train_20, column_mapping=None)

# %%
data_drift_report_100.save_html("data_drift_report_100.html")

# %% [markdown]
# ## Avec 500 nouvelles valeurs

# %%
data_drift_report_500 = Report(metrics=[DataDriftPreset(),])
data_drift_report_500.run(current_data=test_20.iloc[:500], reference_data=train_20, column_mapping=None)

# %%
data_drift_report_500.save_html("data_drift_report_500.html")

# %% [markdown]
# ## Avec 1 000 nouvelles valeurs

# %%
data_drift_report_1000 = Report(metrics=[DataDriftPreset(),])
data_drift_report_1000.run(current_data=test_20.iloc[:1000], reference_data=train_20, column_mapping=None)

# %%
data_drift_report_1000.save_html("data_drift_report_1000.html")

# %%
from sklearn import datasets

from evidently.test_suite import TestSuite
from evidently.test_preset import DataStabilityTestPreset
from evidently.test_preset import DataQualityTestPreset

# %%
data_stability= TestSuite(tests=[
    DataStabilityTestPreset(),
])
data_stability.run(current_data=some_customers2.iloc[:5000], reference_data=trainref.iloc[:10000], column_mapping=None)
data_stability
# Out:
# /opt/anaconda3/envs/openclassrooms/lib/python3.9/site-packages/evidently/metrics/data_integrity/dataset_missing_values_metric.py:147: FutureWarning:
#
# elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons"/>
# <style>
# .reset-this-parent {
#   all: initial;
# }
# .reset-this-parent h5 {
#   all: initial;
#   font: initial;
# }
#
# svg {
#   height: intrinsic !important;
# }
# </style>
# <script>
# ...

# %%
data_stability.save_html("stability.html")

# %% [markdown]
# ## Avec 5 000 nouvelles valeurs

# %%
data_drift_report_5000 = Report(metrics=[DataDriftPreset(),])
data_drift_report_5000.run(current_data=test_20.iloc[:5000], reference_data=train_20, column_mapping=None)

# %%
data_drift_report_5000.save_html("data_drift_report_5000.html")

# %% [markdown]
# ## Avec 10 000 nouvelles valeurs

# %%
data_drift_report_10000 = Report(metrics=[DataDriftPreset(),])
data_drift_report_10000.run(current_data=test_20.iloc[:10000], reference_data=train_20, column_mapping=None)

# %%
data_drift_report_10000.save_html("data_drift_report_10000.html")

# %% [markdown]
# ## Avec 48 744 nouvelles valeurs

# %%
data_drift_report_50000 = Report(metrics=[DataDriftPreset(),])
data_drift_report_50000.run(current_data=test_20.iloc[:50000], reference_data=train_20, column_mapping=None)

# %%
data_drift_report_50000.save_html("data_drift_report_50000.html")

# %% [markdown]
# # Data stability

# %%
from sklearn import datasets

from evidently.test_suite import TestSuite
from evidently.test_preset import DataStabilityTestPreset
from evidently.test_preset import DataQualityTestPreset

# %%
data_stability= TestSuite(tests=[
    DataStabilityTestPreset(),
])
data_stability.run(current_data=some_customers2.iloc[:5000], reference_data=trainref.iloc[:10000], column_mapping=None)
data_stability
# Out:
# /opt/anaconda3/envs/openclassrooms/lib/python3.9/site-packages/evidently/metrics/data_integrity/dataset_missing_values_metric.py:147: FutureWarning:
#
# elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons"/>
# <style>
# .reset-this-parent {
#   all: initial;
# }
# .reset-this-parent h5 {
#   all: initial;
#   font: initial;
# }
#
# svg {
#   height: intrinsic !important;
# }
# </style>
# <script>
# ...

# %%
data_stability.save_html("stability.html")
